# %%
conda install -c anaconda beautifulsoup4
# Out:
# Collecting package metadata (current_repodata.json): | DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# / DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/linux-64/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/linux-64/current_repodata.json HTTP/1.1" 200 None
# - DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/noarch/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/linux-64/current_repodata.json HTTP/1.1" 200 None
# done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::bcrypt==3.2.0=py311h5eee18b_1
#   - defaults/linux-64::scrapy==2.8.0=py311h06a4308_0
#   - defaults/linux-64::anaconda-navigator==2.4.2=py311h06a4308_0
#   - defaults/noarch::conda-content-trust==0.1.1=pyhd3eb1b0_0
#   - defaults/linux-64::twisted==22.10.0=py311h5eee18b_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/linux-64::_anaconda_depends==2023.07=py311_1
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.2
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /home/yv/anaconda3
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.12.2      |  py311h06a4308_0         265 KB  anaconda
#     ca-certificates-2023.08.22 |       h06a4308_0         130 KB  anaconda
#     certifi-2023.7.22          |  py311h06a4308_0         156 KB  anaconda
#     conda-content-trust-0.2.0  |  py311h06a4308_0          60 KB  anaconda
#     openssl-1.1.1w             |       h7f8727e_0         3.8 MB  anaconda
#     pip-23.3                   |  py311h06a4308_0         3.3 MB  anaconda
#     sqlalchemy-2.0.21          |  py311h5eee18b_0         3.8 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:        11.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   pip                anaconda/linux-64::pip-23.3-py311h06a4308_0
#   sqlalchemy         anaconda/linux-64::sqlalchemy-2.0.21-py311h5eee18b_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.05.30~ --> anaconda::ca-certificates-2023.08.22-h06a4308_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust~ --> anaconda/linux-64::conda-content-trust-0.2.0-py311h06a4308_0
#   openssl              pkgs/main::openssl-1.1.1u-h7f8727e_0 --> anaconda::openssl-1.1.1w-h7f8727e_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   beautifulsoup4                                  pkgs/main --> anaconda
#   certifi                                         pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1w       | 3.8 MB    |                                       |   0%
# certifi-2023.7.22    | 156 KB    |                                       |   0%
#
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# ca-certificates-2023 | 130 KB    |                                       |   0%
#
#
# sqlalchemy-2.0.21    | 3.8 MB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
#
#
#
#
# conda-content-trust- | 60 KB     |                                       |   0%
#
#
#
#
# pip-23.3             | 3.3 MB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
#
#
#
#
#
#
# beautifulsoup4-4.12. | 265 KB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/linux-64/sqlalchemy-2.0.21-py311h5eee18b_0.tar.bz2 HTTP/1.1" 200 3981604
#
#
#
# sqlalchemy-2.0.21    | 3.8 MB    | 1                                     |   0% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/linux-64/ca-certificates-2023.08.22-h06a4308_0.tar.bz2 HTTP/1.1" 200 132731
#
#
# ca-certificates-2023 | 130 KB    | ####5                                 |  12% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/linux-64/openssl-1.1.1w-h7f8727e_0.tar.bz2 HTTP/1.1" 200 3998613
# openssl-1.1.1w       | 3.8 MB    | 1                                     |   0% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/linux-64/certifi-2023.7.22-py311h06a4308_0.tar.bz2 HTTP/1.1" 200 160005
#
# certifi-2023.7.22    | 156 KB    | ###7                                  |  10% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/linux-64/conda-content-trust-0.2.0-py311h06a4308_0.tar.bz2 HTTP/1.1" 200 61757
#
#
#
#
# conda-content-trust- | 60 KB     | #########8                            |  27%
#
#
#
# conda-content-trust- | 60 KB     | ##################################### | 100%
#
# ca-certificates-2023 | 130 KB    | ##################################### | 100%
#
# openssl-1.1.1w       | 3.8 MB    | #9                                    |   5%
# certifi-2023.7.22    | 156 KB    | ##################################### | 100% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/linux-64/pip-23.3-py311h06a4308_0.tar.bz2 HTTP/1.1" 200 3456122
#
#
#
#
#
# pip-23.3             | 3.3 MB    | 1                                     |   0%
#
#
# sqlalchemy-2.0.21    | 3.8 MB    | ##8                                   |   8%
# certifi-2023.7.22    | 156 KB    | ##################################### | 100% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/linux-64/beautifulsoup4-4.12.2-py311h06a4308_0.tar.bz2 HTTP/1.1" 200 271600
#
#
#
#
#
#
# openssl-1.1.1w       | 3.8 MB    | ###9                                  |  11%
#
#
#
#
# pip-23.3             | 3.3 MB    | 7                                     |   2%
#
#
# openssl-1.1.1w       | 3.8 MB    | #####6                                |  15%
#
#
#
#
#
# beautifulsoup4-4.12. | 265 KB    | ##########################7           |  72%
#
#
#
#
# pip-23.3             | 3.3 MB    | ##8                                   |   8%
#
#
# openssl-1.1.1w       | 3.8 MB    | #######1                              |  19%
#
#
#
#
#
# beautifulsoup4-4.12. | 265 KB    | ##################################### | 100%
#
#
#
#
# pip-23.3             | 3.3 MB    | ######6                               |  18%
#
#
# openssl-1.1.1w       | 3.8 MB    | ########6                             |  23%
#
#
#
#
# pip-23.3             | 3.3 MB    | ##########5                           |  28%
#
#
# openssl-1.1.1w       | 3.8 MB    | ##########6                           |  29%
#
#
#
#
# openssl-1.1.1w       | 3.8 MB    | ############2                         |  33%
#
#
#
#
# pip-23.3             | 3.3 MB    | ###################4                  |  53%
#
#
# openssl-1.1.1w       | 3.8 MB    | ##############4                       |  39%
#
#
#
#
# pip-23.3             | 3.3 MB    | ######################8               |  62%
#
#
# openssl-1.1.1w       | 3.8 MB    | #################7                    |  48%
#
#
#
#
# pip-23.3             | 3.3 MB    | ##########################1           |  71%
#
#
# openssl-1.1.1w       | 3.8 MB    | ####################                  |  54%
#
#
#
#
# openssl-1.1.1w       | 3.8 MB    | ######################1               |  60%
#
#
# sqlalchemy-2.0.21    | 3.8 MB    | #########################2            |  68%
#
#
#
#
# openssl-1.1.1w       | 3.8 MB    | ########################8             |  67%
#
#
# sqlalchemy-2.0.21    | 3.8 MB    | ###########################2          |  74%
#
#
#
#
# openssl-1.1.1w       | 3.8 MB    | ###########################7          |  75%
#
#
# openssl-1.1.1w       | 3.8 MB    | ###############################       |  84%
#
#
# openssl-1.1.1w       | 3.8 MB    | ##################################1   |  92%
#
#
# openssl-1.1.1w       | 3.8 MB    | ##################################### | 100%
#
#
#
#
# pip-23.3             | 3.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda requests
# Out:
# Collecting package metadata (current_repodata.json): / DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# - DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/linux-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/linux-64/current_repodata.json HTTP/1.1" 304 0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.2
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /home/yv/anaconda3
#
#   added / updated specs:
#     - requests
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     requests-2.31.0            |  py311h06a4308_0         117 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         117 KB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   requests                                        pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
# requests-2.31.0      | 117 KB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /anaconda/linux-64/requests-2.31.0-py311h06a4308_0.tar.bz2 HTTP/1.1" 200 119418
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge spotipy
# Out:
# Collecting package metadata (current_repodata.json): \ DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# | DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/linux-64/current_repodata.json HTTP/1.1" 304 0
# / DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/linux-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/linux-64/current_repodata.json HTTP/1.1" 200 None
# | WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# Solving environment: |
# Warning: 2 possible package resolutions (only showing differing packages):
#   - anaconda/linux-64::openssl-1.1.1w-h7f8727e_0
#   - defaults/linux-64::openssl-1.1.1w-h7f8727edone
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.2
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /home/yv/anaconda3
#
#   added / updated specs:
#     - spotipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.7.22  |       hbcca054_0         146 KB  conda-forge
#     certifi-2023.7.22          |     pyhd8ed1ab_0         150 KB  conda-forge
#     redis-py-5.0.1             |     pyhd8ed1ab_0         167 KB  conda-forge
#     spotipy-2.23.0             |     pyhd8ed1ab_0          30 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         494 KB
#
# The following NEW packages will be INSTALLED:
#
#   redis-py           conda-forge/noarch::redis-py-5.0.1-pyhd8ed1ab_0
#   spotipy            conda-forge/noarch::spotipy-2.23.0-pyhd8ed1ab_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    anaconda::ca-certificates-2023.08.22-~ --> conda-forge::ca-certificates-2023.7.22-hbcca054_0
#   certifi            anaconda/linux-64::certifi-2023.7.22-~ --> conda-forge/noarch::certifi-2023.7.22-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# spotipy-2.23.0       | 30 KB     |                                       |   0%
# redis-py-5.0.1       | 167 KB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
#
#
# ca-certificates-2023 | 146 KB    |                                       |   0%
#
#
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# certifi-2023.7.22    | 150 KB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/certifi-2023.7.22-pyhd8ed1ab_0.conda HTTP/1.1" 200 153791
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/linux-64/ca-certificates-2023.7.22-hbcca054_0.conda HTTP/1.1" 200 149515
#
#
# ca-certificates-2023 | 146 KB    | ####                                  |  11%
#
#
# certifi-2023.7.22    | 150 KB    | ###9                                  |  11% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/redis-py-5.0.1-pyhd8ed1ab_0.conda HTTP/1.1" 200 171400
#
# redis-py-5.0.1       | 167 KB    | ###5                                  |  10% DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/spotipy-2.23.0-pyhd8ed1ab_0.conda HTTP/1.1" 200 31051
# spotipy-2.23.0       | 30 KB     | ##################################### | 100%
#
# ca-certificates-2023 | 146 KB    | ################2                     |  44%
#
#
# certifi-2023.7.22    | 150 KB    | ###############7                      |  43%
# redis-py-5.0.1       | 167 KB    | ############################2         |  76%
#
# ca-certificates-2023 | 146 KB    | ##################################### | 100%
#
#
# certifi-2023.7.22    | 150 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials


c_id = "your client id goes here"
c_se ="your client secret goes here"

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=c_id, client_secret=c_se))
